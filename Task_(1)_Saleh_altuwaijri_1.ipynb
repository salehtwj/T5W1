# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
df = pd.read_csv('/content/Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 4443   9:39:00    Saturday              31-50          Male
# 251   10:47:00    Thursday              31-50          Male
# 4041  22:14:00    Thursday            Over 51          Male
# 2751  18:07:00     Tuesday            Unknown          Male
# 118    1:15:00    Saturday            Unknown        Female
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 4443  Junior high school                Employee              2-5yr
# 251    Elementary school                Employee              1-2yr
# 4041  Junior high school                Employee              2-5yr
# 2751  Junior high school                Employee         Above 10yr
# 118   Junior high school                Employee         Above 10yr
#
#       Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 4443       Automobile            Owner              Above 10yr  ...
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction                 0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace=True)
df['Educational_level'].fillna(df['Educational_level'].mode()[0], inplace=True)
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0], inplace=True)
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace=True)
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0], inplace=True)
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0], inplace=True)

df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0], inplace=True)
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0], inplace=True)
df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mode()[0], inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace=True)
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0], inplace=True)
df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0], inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace=True)
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace=True)
df['Number_of_casualties'].fillna(df['Number_of_casualties'].mode()[0], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction                 0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Casualty_class'].value_counts()
# Out:
# Casualty_class
# Driver or rider    4944
# na                 4443
# Pedestrian         1649
# Passenger          1280
# Name: count, dtype: int64

# %%
df['Sex_of_casualty'].value_counts()
# Out:
# Sex_of_casualty
# Male      5253
# na        4443
# Female    2620
# Name: count, dtype: int64

# %%
#we see that there is 4443 row with null values
# we will drop them

nadf = df[df['Sex_of_casualty'] == 'na']
nadf
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 4       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 10     14:40:00    Saturday              18-30          Male
# ...         ...         ...                ...           ...
# 12307  17:10:00      Friday              31-50          Male
# 12308  17:10:00      Friday              18-30          Male
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12314  13:55:00      Sunday              18-30        Female
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### As you can see there is 4443 row with alot of isuse so we will drop them

# %%
df.drop(nadf.index, inplace=True)

# %%
df['Sex_of_casualty'].value_counts()  # there are clean now
# Out:
# Sex_of_casualty
# Male      5253
# Female    2620
# Name: count, dtype: int64

# %%
df['Work_of_casuality'].value_counts()
# Out:
# Work_of_casuality
# Driver           3811
# Self-employed    1284
# Employee          348
# Other             291
# Student            68
# Unemployed         24
# Unknown             9
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7873 entries, 2 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         7873 non-null   object
#  1   Day_of_week                  7873 non-null   object
#  2   Age_band_of_driver           7873 non-null   object
#  3   Sex_of_driver                7873 non-null   object
#  4   Educational_level            7873 non-null   object
#  5   Vehicle_driver_relation      7873 non-null   object
#  6   Driving_experience           7873 non-null   object
#  7   Type_of_vehicle              7873 non-null   object
#  8   Owner_of_vehicle             7873 non-null   object
#  9   Service_year_of_vehicle      5353 non-null   object
#  10  Defect_of_vehicle            5072 non-null   object
#  11  Area_accident_occured        7873 non-null   object
#  12  Lanes_or_Medians             7873 non-null   object
# ...

# %%
df['Accident_severity'].value_counts()
# Out:
# Accident_severity
# Slight Injury     6634
# Serious Injury    1129
# Fatal injury       110
# Name: count, dtype: int64

# %%
df['Service_year_of_vehicle'].isna().sum()
## we should drop this more 25% of the data are missing
# Out:
# 2520

# %% [markdown]
# ### new i noticed that some columns are not relvent so we will drop the column that we dont want
#
# ###and there is some values more 25% of the data are missing
#
# so we will dorp them

# %%
df = df.drop(['Educational_level' , 'Owner_of_vehicle' , 'Work_of_casuality' , 'Fitness_of_casuality' ],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-0e361192370e> in <cell line: 1>()
# ----> 1 df = df.drop(['Educational_level' , 'Owner_of_vehicle' , 'Work_of_casuality' , 'Fitness_of_casuality' ],axis=1)
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
# ...

# %%
df = df.drop(['Sex_of_casualty' , 'Pedestrian_movement' , 'Defect_of_vehicle' , 'Service_year_of_vehicle' ],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7873 entries, 2 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         7873 non-null   object
#  1   Day_of_week                  7873 non-null   object
#  2   Age_band_of_driver           7873 non-null   object
#  3   Sex_of_driver                7873 non-null   object
#  4   Vehicle_driver_relation      7873 non-null   object
#  5   Driving_experience           7873 non-null   object
#  6   Type_of_vehicle              7873 non-null   object
#  7   Area_accident_occured        7873 non-null   object
#  8   Lanes_or_Medians             7873 non-null   object
#  9   Road_allignment              7873 non-null   object
#  10  Types_of_Junction            7873 non-null   object
#  11  Road_surface_type            7873 non-null   object
#  12  Road_surface_conditions      7873 non-null   object
# ...

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male       7302
# Female      454
# Unknown     117
# Name: count, dtype: int64

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Sex_of_driver'] = df['Sex_of_driver'].replace('Male', '1')
df['Sex_of_driver'] = df['Sex_of_driver'].replace('Female', '0')
df.drop(df[df['Sex_of_driver'] == 'Unknown'].index, inplace=True)
df['Sex_of_driver'] = df['Sex_of_driver'].astype(int)

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# 1    7302
# 0     454
# Name: count, dtype: int64

# %%
df['Driving_experience'].value_counts()
# Out:
# Driving_experience
# 5-10yr        2634
# 2-5yr         1665
# Above 10yr    1417
# 1-2yr         1092
# Below 1yr      856
# No Licence      67
# unknown         25
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7756 entries, 2 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         7756 non-null   object
#  1   Day_of_week                  7756 non-null   object
#  2   Age_band_of_driver           7756 non-null   object
#  3   Sex_of_driver                7756 non-null   int64
#  4   Vehicle_driver_relation      7756 non-null   object
#  5   Driving_experience           7756 non-null   object
#  6   Type_of_vehicle              7756 non-null   object
#  7   Area_accident_occured        7756 non-null   object
#  8   Lanes_or_Medians             7756 non-null   object
#  9   Road_allignment              7756 non-null   object
#  10  Types_of_Junction            7756 non-null   object
#  11  Road_surface_type            7756 non-null   object
#  12  Road_surface_conditions      7756 non-null   object
# ...

# %%
df['Driving_experience'] = df['Driving_experience'].replace('No Licence', '0')
df['Driving_experience'] = df['Driving_experience'].replace('Below 1yr', '1')
df['Driving_experience'] = df['Driving_experience'].replace('Above 10yr', '10')
df['Driving_experience'] = df['Driving_experience'].replace('1-2yr', '1')
df['Driving_experience'] = df['Driving_experience'].replace('2-5yr', '3')
df['Driving_experience'] = df['Driving_experience'].replace('5-10yr', '7')
df['Driving_experience'].value_counts()
# Out:
# Driving_experience
# 7          2634
# 1          1948
# 3          1665
# 10         1417
# 0            67
# unknown      25
# Name: count, dtype: int64

# %%
df.drop(df[df['Driving_experience'] == 'unknown'].index, inplace=True)
df['Driving_experience'] = df['Driving_experience'].astype(int)

# %%
# Out:
# Number_of_vehicles_involved
# <bound method NDFrame.astype of 2        2\n3        2\n5        1\n6        1\n8        2\n        ..\n12305    2\n12309    2\n12310    1\n12313    1\n12315    2\nName: Number_of_vehicles_involved, Length: 7731, dtype: int64>    7731
# Name: count, dtype: int64

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7731 entries, 2 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         7731 non-null   object
#  1   Day_of_week                  7731 non-null   object
#  2   Age_band_of_driver           7731 non-null   object
#  3   Sex_of_driver                7731 non-null   int64
#  4   Vehicle_driver_relation      7731 non-null   object
#  5   Driving_experience           7731 non-null   int64
#  6   Type_of_vehicle              7731 non-null   object
#  7   Area_accident_occured        7731 non-null   object
#  8   Lanes_or_Medians             7731 non-null   object
#  9   Road_allignment              7731 non-null   object
#  10  Types_of_Junction            7731 non-null   object
#  11  Road_surface_type            7731 non-null   object
#  12  Road_surface_conditions      7731 non-null   object
# ...

# %%
df['Light_conditions'].value_counts()
# Out:
# Light_conditions
# Daylight                   5554
# Darkness - lights lit      2046
# Darkness - no lighting      114
# Darkness - lights unlit      17
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Sex_of_driver  Driving_experience  Number_of_casualties
# count    7731.000000         7731.000000           7731.000000
# mean        0.941405            5.115897              1.559824
# std         0.234881            3.323057              1.030272
# min         0.000000            0.000000              1.000000
# 25%         1.000000            1.000000              1.000000
# 50%         1.000000            7.000000              1.000000
# 75%         1.000000            7.000000              2.000000
# max         1.000000           10.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
dfcorr  = df[['Sex_of_driver', 'Driving_experience', 'Number_of_casualties']]
dfcorr.corr()
# Out:
#                       Sex_of_driver  Driving_experience  Number_of_casualties
# Sex_of_driver              1.000000            0.010525              0.059126
# Driving_experience         0.010525            1.000000             -0.027758
# Number_of_casualties       0.059126           -0.027758              1.000000

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
df['Age_band_of_driver'] = df['Age_band_of_driver'].str.capitalize()
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_band_of_driver')
plt.title('Distribution of Age Band of Driver')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(12, 8))
plt.title('Relationship between sex and accident severity')
sns.countplot(data=df, x=df['Sex_of_driver'], hue=df['Accident_severity'])
plt.legend(title='Accident Severity')
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.title('Relationship between wither and accident severity')
sns.countplot(data=df, x=df['Weather_conditions'], hue=df['Accident_severity'])
plt.legend(title='Accident Severity')
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.title('Relationship between rode and accident severity')
sns.countplot(data=df, x=df['Road_surface_conditions'], hue=df['Accident_severity'])
plt.legend(title='Accident Severity')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Accident_severity'], bins=10, kde=True)
plt.title('Distribution of Number of Vehicles Involved')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Frequency')
plt.show()

# %%
plt.pie(df['Age_band_of_driver'].value_counts(), labels=df['Age_band_of_driver'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_band_of_driver', order=df['Age_band_of_driver'].value_counts().index)
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
better_Driver = df.groupby('Sex_of_driver')['Driving_experience'].sum().sort_values()

# %%
plt.figure(figsize=(12, 8))
better_Driver.plot(kind='bar')
plt.xlabel('Gender 1 s men 0 is wemen')
plt.ylabel('Driving experience')
plt.title('who are more expert')
plt.xticks(rotation=90)
plt.show()

# %%
df.plot(kind='scatter', x='Sex_of_driver', y='Driving_experience')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# ##there is no correlation between sex and accident severity
#
#
# ##the data is baisde because most of the draiver are male
#
# ## wether have no effect on the accident severity
#
# ## the road conditions have no effect on the accident severity
#
# ## the driving exp are the same fore both gender
